# %%
import sys
print(sys.executable)
# Out:
# c:\Users\ASUS\python\python.exe

# %%
# !pip install demoji
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: demoji in c:\users\asus\appdata\roaming\python\python38\site-packages (1.1.0)

# %%
import sys
# !{sys.executable} -m pip install demoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting demoji
#   Downloading demoji-1.1.0-py3-none-any.whl.metadata (9.2 kB)
# Downloading demoji-1.1.0-py3-none-any.whl (42 kB)
# Installing collected packages: demoji
# Successfully installed demoji-1.1.0
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import demoji
demoji.download_codes()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_27292\2319952594.py:2: FutureWarning: The demoji.download_codes attribute is deprecated and will be removed from demoji in a future version. It is an unused attribute as emoji codes are now distributed directly with the demoji package.
#   demoji.download_codes()

# %%
import demoji

text = "Good morning! ☀️🌸"
a1 = demoji.replace(text, "")
print(a1)
# Out:
# Good morning!

# %%
import demoji

text = "Happy birthday! 🎂🎈"
a1 = demoji.replace_with_desc(text)
print(a1)
# Out:
# Happy birthday! :birthday cake::balloon:

# %%
import demoji
text = "Good morning ☀️😊"
emojis = demoji.findall(text)
print(emojis)
# Out:
# {'😊': 'smiling face with smiling eyes', '☀️': 'sun'}

# %%
import demoji

text = "Welcome to the party! 🎉🥳"
a1 = demoji.replace(text, "")
print(a1)
# Out:
# Welcome to the party!
